# %% [markdown]
# # San Francisco International Airport (SFO) Passenger Traffic Analysis
#
# This notebook analyzes monthly passenger traffic statistics by airline at SFO, using [data from the San Francisco Open Data Portal](https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg/).
#
# **Data Source Notes:**
# * Airport data is seasonal; compare period-over-period (e.g., Jan 2010 vs. Jan 2009).
# * Fact and attribute field relationships are not always 1-to-1 (e.g., United Airlines passenger counts may appear in multiple attribute fields and are additive).
#
# Let's load the data and perform initial exploration.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('air-traffic-passenger-statistics.csv')
df
# Out:
#        Activity Period Activity Period Start Date  \
# 0               199907                 1999/07/01
# 1               199907                 1999/07/01
# 2               199907                 1999/07/01
# 3               199907                 1999/07/01
# 4               199907                 1999/07/01
# ...                ...                        ...
# 37511           202501                 2025/01/01
# 37512           202501                 2025/01/01
# 37513           202501                 2025/01/01
# 37514           202501                 2025/01/01
# 37515           202501                 2025/01/01
#
#                              Operating Airline Operating Airline IATA Code  \
# 0                                 ATA Airlines                          TZ
# 1                                 ATA Airlines                          TZ
# 2                                 ATA Airlines                          TZ
# ...
