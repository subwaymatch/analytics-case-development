# %% [markdown]
# # Natural Language Processing Introduction
#
# Natural language processing (NLP) aims to give computers the ability to understand, process, and even generate human language. This notebook introduces the common preprocessing steps and demonstrates how to use a widely used transformer model (`distilbert-base-uncased-finetuned-sst-2-english`) to perfrom sentiment analysis. 😀😦🙁

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Load data
#
# This exercise uses a small sampled dataset that contains reviews of property management companies in campustowns.

# %%
df_b = pd.read_csv(
    'https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/businesses-sample.csv'
)
df_r = pd.read_csv(
    'https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/reviews-sample.csv',
    parse_dates = ['review_datetime_utc', 'owner_answer_timestamp_datetime_utc']
)

# %%
display(df_b.head(2))
display(df_r.head(2))
# Out:
#                            campus                     place_id  \
# 0  Indiana University Bloomington  ChIJY1yB5NJmbIgRZn7E2oF5gVQ
# 1  Indiana University Bloomington  ChIJPb8SbdpnbIgR82bkOLSKtZM
#
#                           name  \
# 0  State On Campus Bloomington
# 1  The Standard at Bloomington
#
#                                                 site                category  \
# 0  https://stateoncampus.com/bloomington/?utm_sou...       Apartment complex
# 1  https://www.thestandardbloomington.com/?utm_so...  Student housing center
#
#    borough            street         city  postal_code    state   latitude  \
# 0      NaN  2036 N Walnut St  Bloomington        47404  Indiana  39.184846
# 1      NaN     250 E 14th St  Bloomington        47408  Indiana  39.175974
#
#    longitude  verified
# 0 -86.532875      True
# 1 -86.531609      True
#                       place_id                            review_id  \
# 0  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE
# 1  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChZDSUhNMG9nS0VJQ0FnSUNaOC15NkhBEAE
#
#                author_id  author_title  \
# 0  109839330111495228413    Aziz Bohra
# 1  102607480175477014087  Nessa Bacher
#
#                                          review_text  review_rating  \
# 0  This place has my heart! Spacious rooms, quali...              5
# 1  I’ll start with the positives of living at Sta...              4
#
#                                       review_img_url  \
# 0  https://lh5.googleusercontent.com/p/AF1QipM0Jm...
# 1                                                NaN
#
#         review_datetime_utc  \
# 0 2023-04-01 03:19:15+00:00
# 1 2023-09-25 00:17:21+00:00
#
#                                         owner_answer  \
# 0  Thanks for your feedback.  We are grateful tha...
# 1  We are so pleased to hear that you enjoy livin...
#
#   owner_answer_timestamp_datetime_utc  review_likes
# 0           2022-11-01 18:54:45+00:00             0
# 1           2023-09-18 14:20:59+00:00             0

# %% [markdown]
# ## 🪓 Tokenization using spaCy

# %%
import spacy

# %% [markdown]
# ### Trained pipelines
#
# Trained pipelines are models that enable spaCy to predict linguistic attributes in context
#
# - Part-of-speech tags
# - Syntactic dependencies
# - Named entities
#
# `'en_core_web_sm'` is a English pipeline optimized for CPU.
#
# Components:
#
# - tok2vec
# - taggerparser
# - senter
# - ner
# - attribute_ruler
# - lemmatizer

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = 'I love this apartment'
doc = nlp(text)

for token in doc:
    print('------------------')
    print(f'text: {token.text}')
    print(f'lemma: {token.lemma_}')
    print(f'pos: {token.pos_}') # pos_ stands for part-of-speech
    print(f'explain: {spacy.explain(token.pos_)}')
    print(f'is_stop: {token.is_stop}')
# Out:
# ------------------
# text: I
# lemma: I
# pos: PRON
# explain: pronoun
# is_stop: True
# ------------------
# text: love
# lemma: love
# pos: VERB
# explain: verb
# is_stop: False
# ------------------
# text: this
# lemma: this
# pos: DET
# explain: determiner
# is_stop: True
# ------------------
# text: apartment
# lemma: apartment
# pos: NOUN
# explain: noun
# is_stop: False

# %% [markdown]
# We can visualize the parse tree using `displacy`.

# %%
from spacy import displacy

displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2cc8c218764449bbf7b143492ed329a-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">apartment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2cc8c218764449bbf7b143492ed329a-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2cc8c218764449bbf7b143492ed329a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2cc8c218764449bbf7b143492ed329a-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2cc8c218764449bbf7b143492ed329a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2cc8c218764449bbf7b143492ed329a-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2cc8c218764449bbf7b143492ed329a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Tokenization and lemmatization
#
# Tokenization takes a piece of text and breaks it down into meaningful units called "tokens." These tokens can be individual words, punctuation marks, numbers, or even phrases depending on the task and chosen method.
#
# Lemmatization goes a step further, focusing on the "base form" or "dictionary form" of words. It groups together different grammatical variations of the same word (like "playing," "plays," "played") and reduces them to their core meaning ("play"). This helps capture the true meaning of the text regardless of how they are used.

# %%
cols = ["text", "lemma", "pos", "explain", "is_stop"]
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df_tokens = pd.DataFrame(rows, columns=cols)
df_tokens
# Out:
#         text      lemma   pos     explain  is_stop
# 0          I          I  PRON     pronoun     True
# 1       love       love  VERB        verb    False
# 2       this       this   DET  determiner     True
# 3  apartment  apartment  NOUN        noun    False

# %%
cols = ["review_id", "text", "lemma", "pos", "explain", "is_stop"]
rows = []

for index, row in df_r[df_r['review_text'].notna()].iterrows():
    doc = nlp(row['review_text'])
    for t in doc:
        new_row = [row['review_id'], t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
        rows.append(new_row)

df_tokens = pd.DataFrame(rows, columns=cols)
df_tokens
# Out:
#                                  review_id    text   lemma    pos  \
# 0      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE    This    this    DET
# 1      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE   place   place   NOUN
# 2      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE     has    have   VERB
# 3      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE      my      my   PRON
# 4      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE   heart   heart   NOUN
# ...                                    ...     ...     ...    ...
# 18255  ChZDSUhNMG9nS0VJQ0FnSUNSdUpEV2FREAE       !       !  PUNCT
# 18256  ChZDSUhNMG9nS0VJQ0FnSUNSeUp1dUVBEAE  Hooray  Hooray  PROPN
# 18257  ChZDSUhNMG9nS0VJQ0FnSUNSeUp1dUVBEAE       !       !  PUNCT
# 18258  ChZDSUhNMG9nS0VJQ0FnSUR4aDZQckl3EAE   wowie   wowie  PROPN
# 18259  ChZDSUhNMG9nS0VJQ0FnSUR4aDZQckl3EAE    zowa    zowa  PROPN
#
#            explain  is_stop
# 0       determiner     True
# 1             noun    False
# 2             verb     True
# 3          pronoun     True
# 4             noun    False
# ...            ...      ...
# 18255  punctuation    False
# 18256  proper noun    False
# 18257  punctuation    False
# 18258  proper noun    False
# 18259  proper noun    False
#
# [18260 rows x 6 columns]

# %% [markdown]
# ### Remove stop words
#
# Stop words, as you might guess from the name, are a set of commonly used words in a language that are often filtered out before processing text in Natural Language Processing (NLP) tasks. These words, like "the," "a," "is," "and," "on," etc., are considered to carry little independent meaning and contribute minimally to the overall understanding of the text.
#
# We remove the stop words here for two reasons:
#
# 1. Reduce noise: By removing commonly used words, we focus on the content-rich keywords that convey the core meaning of the text.
# 2. Improve efficiency: Removing stop words reduces the overall size of the data, making NLP tasks faster and less computationally expensive.

# %%
# only filter non stop words
df_tokens_filtered = df_tokens[~df_tokens['is_stop']]

# remove words shorter than 4 characters long
df_tokens_filtered = df_tokens_filtered[df_tokens_filtered['lemma'].str.len() >= 4]

df_tokens_filtered
# Out:
#                                  review_id      text     lemma    pos  \
# 1      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE     place     place   NOUN
# 4      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE     heart     heart   NOUN
# 6      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE  Spacious  spacious    ADJ
# 7      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE     rooms      room   NOUN
# 9      ChZDSUhNMG9nS0VJQ0FnSUMtbE1XaWR3EAE   quality   quality   NOUN
# ...                                    ...       ...       ...    ...
# 18252  ChZDSUhNMG9nS0VJQ0FnSUNSdUpEV2FREAE     staff     staff   NOUN
# 18254  ChZDSUhNMG9nS0VJQ0FnSUNSdUpEV2FREAE   awesome   awesome    ADJ
# 18256  ChZDSUhNMG9nS0VJQ0FnSUNSeUp1dUVBEAE    Hooray    Hooray  PROPN
# 18258  ChZDSUhNMG9nS0VJQ0FnSUR4aDZQckl3EAE     wowie     wowie  PROPN
# 18259  ChZDSUhNMG9nS0VJQ0FnSUR4aDZQckl3EAE      zowa      zowa  PROPN
#
#            explain  is_stop
# 1             noun    False
# 4             noun    False
# 6        adjective    False
# 7             noun    False
# 9             noun    False
# ...            ...      ...
# 18252         noun    False
# 18254    adjective    False
# 18256  proper noun    False
# 18258  proper noun    False
# 18259  proper noun    False
#
# [5949 rows x 6 columns]

# %% [markdown]
# Display value counts.

# %%
df_tokens_filtered['lemma'].value_counts()
# Out:
# lemma
# apartment    125
# live         119
# place         99
# staff         71
# great         62
#             ...
# discard        1
# needle         1
# massive        1
# forever        1
# zowa           1
# Name: count, Length: 1457, dtype: int64

# %% [markdown]
# ## 🧪 Sentiment analysis using distilbert

# %% [markdown]
# From [Hugging Face's Documentation](https://huggingface.co/docs/transformers/main/en/index):
#
# > Transformers provides APIs and tools to easily download and train state-of-the-art pretrained models. Using pretrained models can reduce your compute costs, carbon footprint, and save you the time and resources required to train a model from scratch. These models support common tasks in different modalities, such as:
#
# > 📝 **Natural Language Processing**: text classification, named entity recognition, question answering, language modeling, summarization, translation, multiple choice, and text generation.

# %%
! pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (4.35.2)
# Requirement already satisfied: filelock in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from transformers) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/tljh/user/lib/python3.9/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jupyter-subwaymatch/.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/tljh/user/lib/python3.9/site-packages (from requests->transformers) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests->transformers) (3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests->transformers) (2022.12.7)

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
# Out:
# 2023-12-05 19:31:24.017784: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 19:31:24.096098: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 19:31:24.096150: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 19:31:24.097781: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 19:31:24.107923: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 19:31:24.109070: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-05 19:31:26.030476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# 2023-12-05 19:31:28.686983: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
# 2023-12-05 19:31:29.193321: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
# 2023-12-05 19:31:29.223920: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
# 2023-12-05 19:31:31.049435: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
# 2023-12-05 19:31:31.132100: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %% [markdown]
# ### Run sentiment classifier

# %%
classifier("We are very happy to show you the 🤗 Transformers library.")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997795224189758}]

# %%
classifier("These thieves tried to steal my security deposit.")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.996752142906189}]

# %% [markdown]
# ### Sample 30 rows for in-class exercise

# %% [markdown]
# Although the `distilbert-base-uncased-finetuned-sst-2-english` model is pre-trained and distilled (40% smaller than the original BERT model), it will still be slow to be used for the entire dataset.
#
# For in-class exercise, only sample 30 rows where review_rating is less than or equal to 4 out of 5 stars.

# %%
df_sample = df_r[df_r['review_rating'] <= 4].sample(30)

# %% [markdown]
# Create two new columns to store sentiment labels and scores.

# %%
df_sample['sentiment'] = np.nan
df_sample['score'] = np.nan

# %% [markdown]
# Run sentiment analysis.

# %%
num_rows = df_sample.shape[0]

for i in range(num_rows):
  # grab review text to a variable
  review_text = df_sample['review_text'].iloc[i]

  # calculate sentiments for non-missing review texts
  # the model supports up to 512 tokens
  # truncate longer texts
  if pd.notna(review_text):
    result = classifier(
        review_text,
        truncation=True,
        padding=True,
        max_length=512
    )
    
    df_sample.iloc[i, df_sample.columns.get_loc('sentiment')] = result[0]['label']
    df_sample.iloc[i, df_sample.columns.get_loc('score')] = result[0]['score']

  # display progress
  progress_percentage = round((i + 1) / num_rows * 100, 2)
  print(f'{i + 1}/{num_rows} ({progress_percentage}%)', end=' ')

  if (i + 1) % 10 == 0:
    print('')

print('====================')
print('Complete')
# Out:
# /tmp/ipykernel_2100587/2539895619.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'POSITIVE' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_sample.iloc[i, df_sample.columns.get_loc('sentiment')] = result[0]['label']
# 1/30 (3.33%) 2/30 (6.67%) 3/30 (10.0%) 4/30 (13.33%) 5/30 (16.67%) 6/30 (20.0%) 7/30 (23.33%) 8/30 (26.67%) 9/30 (30.0%) 10/30 (33.33%)
# 11/30 (36.67%) 12/30 (40.0%) 13/30 (43.33%) 14/30 (46.67%) 15/30 (50.0%) 16/30 (53.33%) 17/30 (56.67%) 18/30 (60.0%) 19/30 (63.33%) 20/30 (66.67%)
# 21/30 (70.0%) 22/30 (73.33%) 23/30 (76.67%) 24/30 (80.0%) 25/30 (83.33%) 26/30 (86.67%) 27/30 (90.0%) 28/30 (93.33%) 29/30 (96.67%) 30/30 (100.0%)
# ====================
# Complete

# %%
df_sample
# Out:
#                         place_id                             review_id  \
# 88   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUN3eTZ6QXlnRRAB
# 50   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUMwajlQb2NREAE
# 184  ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSURnd3J6TkpREAE
# 54   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNZbWItUV9BRRAB
# 185  ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNnMXE2N0lREAE
# 19   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNlLVlhMzV3RRAB
# 148  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUN3M2ItUjVnRRAB
# 207  ChIJPb8SbdpnbIgR82bkOLSKtZM  ChdDSUhNMG9nS0VJQ0FnSUNseExTTWx3RRAB
# 117  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNlZ0pfcGlBRRAB
# 168  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNBcU43X2hRRRAB
# 146  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSURRbGVDRzdRRRAB
# 87   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSURTamJ1OENBEAE
# 53   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNnMDhEUEd3EAE
# 82   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNndmVidzFnRRAB
# 164  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSURRanQtS2p3RRAB
# 173  ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNjMzluc2J3EAE
# 136  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNBcU9URzJ3RRAB
# 110  ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNpdFB1Skp3EAE
# 193  ChIJPb8SbdpnbIgR82bkOLSKtZM   ChZDSUhNMG9nS0VJQ0FnSURaMmUtdUlREAE
# 20   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSURHeUtfd3NBRRAB
# 203  ChIJPb8SbdpnbIgR82bkOLSKtZM  ChdDSUhNMG9nS0VJQ0FnSURGdGFuQjZ3RRAB
# 26   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUR5LXFYcFp3EAE
# 71   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSURXdGY2NUZREAE
# 33   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSURLdUlIbmVnEAE
# 15   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUR1eTRxUDhBRRAB
# 196  ChIJPb8SbdpnbIgR82bkOLSKtZM   ChZDSUhNMG9nS0VJQ0FnSURwbVpqMmVnEAE
# 1    ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNaOC15NkhBEAE
# 160  ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSUNXMEx6OHJ3RRAB
# 63   ChIJY1yB5NJmbIgRZn7E2oF5gVQ   ChZDSUhNMG9nS0VJQ0FnSUNDX3NPaFVBEAE
# 55   ChIJY1yB5NJmbIgRZn7E2oF5gVQ  ChdDSUhNMG9nS0VJQ0FnSURZeEozWXp3RRAB
#
#                  author_id      author_title  \
# 88   107921325574085425680                 J
# 50   102119770053957405964     Hannah Miller
# 184  117784691122254913422          Leo Cabr
# 54   104270285434832150877        Anna Peura
# 185  115211396667741977481        Derek Oden
# 19   110019894227513393757        KJen Howie
# 148  111649617446437780997       Jacci Carey
# 207  105558539338032788154      Elena Wilson
# 117  104610055701729616913       Newmi Oldmi
# 168  117278245074325192982       jake watson
# 146  104967650450271853817     Kyung Jin Yoo
# 87   108803138820809330255       Ana Peixoto
# 53   100574004448443658337     Autumn Taylor
# 82   106931341108579253523  Joseph Gallagher
# 164  116262941842374703640      Kyle Andrews
# 173  109804792570428447598         Tad Davis
# 136  107244556036976592377       DAE GOO Won
# 110  111669024045891112596       Isaiah Reed
# 193  115971162678632931679      Elai Spector
# 20   109531860142413505522        Emma Scott
# 203  104371080600333741951    Kristen Oliver
# 26   104489235580360487774  Destinyy Murrayy
# 71   115821743723727786892    kaitlin matson
# 33   114158591505828528239    Alayna witters
# 15   114139735823779959640   Noelle Humphrey
# 196  109463685318607123996         Anonymous
# 1    102607480175477014087      Nessa Bacher
# 160  104893436245871627381        Jared Dyer
# 63   101612918349859145936      Macenzie Ash
# 55   103775027831073020100     Netflix Perry
#
#                                            review_text  review_rating  \
# 88   Great place to live! But when it gets snowy it...              3
# 50   The price is inexpensive for how nice the apar...              4
# 184                                                NaN              1
# 54   Management here is not that great. I understan...              1
# 185                                                NaN              3
# 19   Chill on the No prorates. I promise you and yo...              1
# 148                                                NaN              1
# 207  ** The reason there are so many positive revie...              2
# 117  Rude management and yes I’m talking about you ...              1
# 168                                                NaN              1
# 146                                                NaN              1
# 87   This complex is a joke. They don’t answer your...              1
# 53   DO NOT LIVE HERE!!!!\nManagement is horrible a...              1
# 82   I complained on several ocassions of the trash...              1
# 164                                                NaN              4
# 173                                                NaN              4
# 136          The worst apartment that I have lived in.              1
# 110  Office staff was great every time I had a ques...              4
# 193  Avoid living here at all costs. The other revi...              1
# 20   The apartments themselves look nice as they ar...              2
# 203  Visited the Standard to take a tour a few days...              1
# 26   This place is the absolute worse. They get mon...              1
# 71   Everything in the apartments are cheap and har...              1
# 33   Worst apartment complex you could live at in B...              1
# 15   If I could give them 0 stars I would. I sublea...              1
# 196  There is a big lack of communication around ma...              1
# 1    I’ll start with the positives of living at Sta...              4
# 160                                                NaN              3
# 63   This is the most horrible apartment complex I ...              1
# 55   Absolute terrible place to live. A complete sc...              1
#
#     review_img_url       review_datetime_utc  \
# 88             NaN 2018-01-15 17:15:59+00:00
# 50             NaN 2019-10-14 21:14:49+00:00
# 184            NaN 2018-08-23 19:38:26+00:00
# 54             NaN 2019-04-15 18:03:05+00:00
# 185            NaN 2018-07-02 09:25:34+00:00
# 19             NaN 2022-09-18 16:01:57+00:00
# 148            NaN 2018-06-08 19:35:53+00:00
# 207            NaN 2023-11-14 03:48:19+00:00
# 117            NaN 2022-09-03 02:39:35+00:00
# 168            NaN 2018-09-07 20:47:49+00:00
# 146            NaN 2018-05-14 00:39:48+00:00
# 87             NaN 2021-01-04 16:16:16+00:00
# 53             NaN 2017-05-23 22:29:15+00:00
# 82             NaN 2018-04-19 00:28:40+00:00
# 164            NaN 2017-08-22 20:56:21+00:00
# 173            NaN 2020-05-09 03:35:42+00:00
# 136            NaN 2016-07-28 01:46:09+00:00
# 110            NaN 2021-07-28 16:38:41+00:00
# 193            NaN 2023-10-04 11:49:06+00:00
# 20             NaN 2021-11-16 19:27:11+00:00
# 203            NaN 2023-11-09 00:57:41+00:00
# 26             NaN 2021-03-04 22:45:13+00:00
# 71             NaN 2022-03-30 21:07:49+00:00
# 33             NaN 2021-04-29 13:31:56+00:00
# 15             NaN 2022-08-29 15:51:49+00:00
# 196            NaN 2023-08-24 20:09:01+00:00
# 1              NaN 2023-09-25 00:17:21+00:00
# 160            NaN 2022-03-20 23:32:31+00:00
# 63             NaN 2020-08-24 19:22:27+00:00
# 55             NaN 2019-04-29 22:22:06+00:00
#
#                                           owner_answer  \
# 88   Thank you for your review. We are glad you are...
# 50                                                 NaN
# 184                                                NaN
# 54                                                 NaN
# 185                                                NaN
# 19   Thank you for your feedback, KJen. We are than...
# 148                                                NaN
# 207  Hey Elena, thank you for your review. We are i...
# 117  Hi there, Newmi. We cannot find you in our sys...
# 168                                                NaN
# 146  Hello, please let us know how we can improve o...
# 87                                                 NaN
# 53   Hello Autumn, please allow me this opportunity...
# 82   Hello Mr. Gallagher,\nWe are not showing you a...
# 164                                                NaN
# 173                                                NaN
# 136  Hello Mr. Dea Goo Won,\nWe see that you had po...
# 110  Thank you for the kind review. If there is any...
# 193  Thank you so much for your feedback. We are al...
# 20   Hi Emma, thank you for your feedback. We are d...
# 203  Hi Kristen! So sorry that was your expeirence....
# 26                                                 NaN
# 71   Thank you for bringing this concern to our att...
# 33                                                 NaN
# 15   Noelle, thank you for your feedback. We hope t...
# 196  Thank you for taking the time to leave a revie...
# 1    We are so pleased to hear that you enjoy livin...
# 160  Thank you so much for the review! We hope to h...
# 63                                                 NaN
# 55   Hello, Congrats on graduating! I’m sorry that ...
#
#     owner_answer_timestamp_datetime_utc  review_likes sentiment     score
# 88            2018-01-15 19:12:02+00:00             0  POSITIVE  0.922939
# 50                                  NaT             0  POSITIVE  0.999724
# 184                                 NaT             0       NaN       NaN
# 54                                  NaT             7  NEGATIVE  0.999542
# 185                                 NaT             0       NaN       NaN
# 19            2022-09-19 14:30:09+00:00             5  NEGATIVE  0.998130
# 148                                 NaT             0       NaN       NaN
# 207           2023-11-14 17:27:22+00:00             2  NEGATIVE  0.999679
# 117           2022-09-05 15:31:47+00:00             5  NEGATIVE  0.850365
# 168                                 NaT             0       NaN       NaN
# 146           2018-05-16 11:53:41+00:00             0       NaN       NaN
# 87                                  NaT            10  NEGATIVE  0.999681
# 53            2017-05-31 20:57:02+00:00             7  NEGATIVE  0.999804
# 82            2018-04-19 01:01:47+00:00             4  NEGATIVE  0.999705
# 164                                 NaT             0       NaN       NaN
# 173                                 NaT             0       NaN       NaN
# 136           2016-09-26 15:43:38+00:00             4  NEGATIVE  0.999788
# 110           2021-10-15 14:00:25+00:00             0  POSITIVE  0.999755
# 193           2023-10-04 12:51:07+00:00             4  NEGATIVE  0.999608
# 20            2021-11-17 16:00:22+00:00            10  NEGATIVE  0.999082
# 203           2023-11-09 15:30:32+00:00             1  NEGATIVE  0.997406
# 26                                  NaT            11  NEGATIVE  0.999731
# 71            2022-04-04 20:03:10+00:00             7  NEGATIVE  0.999512
# 33                                  NaT            12  NEGATIVE  0.999808
# 15            2022-08-30 12:32:33+00:00             6  NEGATIVE  0.999707
# 196           2023-08-25 20:45:07+00:00             8  NEGATIVE  0.999677
# 1             2023-09-18 14:20:59+00:00             0  POSITIVE  0.977032
# 160           2022-02-15 21:00:29+00:00             0       NaN       NaN
# 63                                  NaT            11  NEGATIVE  0.999559
# 55            2019-05-17 10:52:29+00:00             7  NEGATIVE  0.998785
